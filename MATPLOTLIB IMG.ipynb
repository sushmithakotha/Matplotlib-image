# %%
# plotting numpy array as image so we have a data in numpy array
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread("C:\\Users\\Kotha Maheshwari\\Dropbox\\Kotha Maheshwari\\My PC (LAPTOP-9NU57QAJ)\\Downloads\\python img.JPG")
print(img)
imgplot = plt.imshow(img)
# Out:
# [[[105 105 105]
#   [104 104 104]
#   [103 103 103]
#   ...
#   [109 109 109]
#   [109 109 109]
#   [109 109 109]]
#
#  [[106 106 106]
#   [105 105 105]
#   [105 105 105]
#   ...
#   [110 110 110]
#   [110 110 110]
#   [110 110 110]]
#
#  [[107 107 107]
#   [107 107 107]
#   [106 106 106]
#   ...
#   [110 110 110]
#   [110 110 110]
#   [110 110 110]]
#
#  ...
#
#  [[113 113 113]
#   [111 111 111]
#   [109 109 109]
#   ...
#   [115 115 115]
#   [115 115 115]
#   [115 115 115]]
#
#  [[114 114 114]
#   [113 113 113]
#   [112 112 112]
#   ...
#   [115 115 115]
#   [114 114 114]
#   [114 114 114]]
#
#  [[114 114 114]
#   [114 114 114]
#   [114 114 114]
#   ...
#   [114 114 114]
#   [114 114 114]
#   [113 113 113]]]

# %%
# Applying pseudocolor schemes to image plots
lum_img = img[:,:,0]
plt.imshow(lum_img,cmap = 'hot')

# %%
#Applying pseudocolor schemes to image plots
lum_img = img[:,:,0]
plt.imshow(lum_img,cmap = 'cool')

# %%
# using pillow library used to load image and resize image
from PIL import Image
img = Image.open("C:\\Users\\Kotha Maheshwari\\Dropbox\Kotha Maheshwari\\My PC (LAPTOP-9NU57QAJ)\\Downloads\\python img.JPG")
img.thumbnail((64,64),Image.ANTIALIAS)
imgplot = plt.imshow(img)

# %%
#change colormaps on existing plot helpful for enhancing contrast and visualising data
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('nipy_spectral')

# %%
# color scale reference have an idea what value a color represent
imgplot = plt.imshow(lum_img)
plt.colorbar()
